# %%
import pandas as pd

# 1. Load the Red Wine data
red_wine_df = pd.read_csv('winequality-red.csv', sep=';')
print("Red Wine DataFrame loaded.")

# 2. Load the White Wine data
white_wine_df = pd.read_csv('winequality-white.csv', sep=';')
print("White Wine DataFrame loaded.")

# 3. Quick check of the data (optional, but highly recommended)
print("\n--- First 5 rows of Red Wine Data ---")
print(red_wine_df.head(5))
    
# 4. Print the Dataframe Summary
print(red_wine_df.info())
print (white_wine_df.info())

# 5. Print the statistics of the dataframe
print(red_wine_df.describe())
print(white_wine_df.describe())

# 6. Print the shape of dataframe 
print(red_wine_df.shape)
print(white_wine_df.shape)

# 7. Print the datatype of each column
print(red_wine_df.dtypes)
print(white_wine_df['alcohol'].dtype)

# 8. Check the missing values
print(red_wine_df.isnull().sum())
print(white_wine_df.isnull().sum())

# 9. Drop the column containing missing values
print(red_wine_df.dropna())
print(white_wine_df.dropna())

# 10.
# Out:
# Red Wine DataFrame loaded.
# White Wine DataFrame loaded.
#
# --- First 5 rows of Red Wine Data ---
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# ...
