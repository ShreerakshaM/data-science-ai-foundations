# %%
import pandas as pd

# Create DataFrame
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [24, 26, 23]
}

df = pd.DataFrame(data)
df
# Out:
#       name  age
# 0    Alice   24
# 1      Bob   26
# 2  Charlie   23
